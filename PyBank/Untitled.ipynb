# %%
# Import the pathlib and csv library
from pathlib import Path
import csv

# Check the current directory where the Python program is executing from
print(f"Current Working Directory: {Path.cwd()}")

# Set the file path
csvpath = Path ('budget_data.csv')
print(csvpath)

# Initialize line_num variable
line_num = 0


# Open the file in "read" mode ('r') and store the contents in the variable 'csvfile'
with open(csvpath, 'r') as csvfile:
    
    # Csv file to the csv.reader() function (with ',' as the delmiter/separator)
    csvreader = csv.reader(csvfile, delimiter=',')
    
    # Go to the next row from the start of the file and iterate line_num by 1
    header = next(csvreader)
    line_num += 1
    
    # Initialize variables
    total_months = 0
    net_profitnlosses = 0
    count_profitnlosses = 0
    average_change_profitnlosses = 0
    
    # Calculate loops
    for row in csvreader:
        
        # Count the total number of months included in the dataset
        total_months += 1
        count_profitnlosses += 1
        
        # Change of Profit / Losses variable
        change_profitnlosses = int(row[1]) - profitnlosses
        print(change_profitnlosses)
        
        # Calculate the net total of Profit/losses over the entire period
        profitnlosses = int(row[1])
        net_profitnlosses += profitnlosses

        # Calculate the average of the changes in Profit/Losses over the entire period.
        total_change_profitnlosses += change_profitnlosses
        #average_change_profitnlosses = total_change_profitnlosses / count_profitnlosses
        
    #check value is correct
    print(f"Total Months: {total_months}")
    print(f"Net Total of Profit/Losses: ${net_profitnlosses}")
    print(total_change_profitnlosses)
# Out:
# Current Working Directory: C:\Users\Rae\Desktop\Week 2 homework\Python-Homework\PyBank
# budget_data.csv
# 196785
# 116771
# -662642
# -391430
# 379920
# 212354
# 510239
# -428211
# -821271
# 693918
# 416278
# -974163
# 860159
# -1115009
# 1033048
# 95318
# -308093
# 99052
# -521393
# 605450
# 231727
# -65187
# -702716
# 177975
# -1065544
# 1926159
# -917805
# 898730
# -334262
# -246499
# -64055
# -1529236
# 1497596
# 304914
# -635801
# 398319
# -183161
# -37864
# -253689
# 403655
# 94168
# 306877
# -83000
# 210462
# -2196167
# 1465222
# -956983
# 1838447
# -468003
# -64602
# 206242
# -242155
# -449079
# 315198
# 241099
# 111540
# 365942
# -219310
# -368665
# 409837
# 151210
# -110244
# -341938
# -1212159
# 683246
# -70825
# 335594
# 417334
# -272194
# -236462
# 657432
# -211262
# -128237
# -1750387
# 925441
# 932089
# -311434
# 267252
# -1876758
# 1733696
# 198551
# -665765
# 693229
# -734926
# 77242
# 532869
# Total Months: 86
# Net Total of Profit/Losses: $38382578
# 0
